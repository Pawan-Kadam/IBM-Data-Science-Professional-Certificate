# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **PAWAN KADAM** <br>
# I am an undergraduate student.

# %% [markdown]
# *I am interested in data science because I am very curious about data and love to gain insights from the data*

# %% [markdown]
# ### Below is the code to find sum of first 50 number

# %%
n = 50
sum = n*(n+1)/2
print(sum)
# Out:
# 1275.0

# %% [markdown]
# ***
# __[Google_Link](http://google.com)__ <br>
# ***
#  - Bulleted List1
#      - Bulleted List2
